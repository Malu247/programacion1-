# %% [markdown]
# <a href="https://colab.research.google.com/github/Malu247/programacion1-/blob/main/phyton2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Estructura de datos en Python**

# %% [markdown]
# Listas

# %%
cubos = [1,8,27,65,123]

# %%
cubos[3:]=64, 125
print(cubos)
# Out:
# [1, 8, 27, 64, 125]

# %%
cubos.append(6**3)
print(cubos)
# Out:
# [1, 8, 27, 64, 125, 64, 64, 216, 216, 216]

# %%
cubos[5:]=[]
cubos
# Out:
# [1, 8, 27, 64, 125]

# %%
numero_complejo=3+76j

print(numero_complejo, type(numero_complejo))
# Out:
# (3+76j) <class 'complex'>

# %%
letras = ["a","b","c","d","e"]

# %%
letras[2:5]=["C","D","E"]
print(letras)
# Out:
# ['a', 'b', 'C', 'D', 'E']

# %%
letras[3:5]=[]
print(letras)
# Out:
# ['a', 'b', 'C']

# %%
x=[letras,cubos]
x
# Out:
# [['a', 'b', 'C'], [1, 8, 27, 64, 125, 64, 64, 216, 216, 216]]

# %%
n=[letras,cubos,5]
n
# Out:
# [['a', 'b', 'C'], [1, 8, 27, 64, 125], 5]

# %%
print(n[0])
# Out:
# ['a', 'b', 'C']

# %%
n[1][2]
# Out:
# 27

# %%
i=256*256
print("El valor de i es",i)
# Out:
# El valor de i es 65536

# %%
numero_complejo**3
# Out:
# (-51957-436924j)

# %%
a = "casa"
b = "carro"
a == b
# Out:
# False

# %%
from typing import no_type_check
s=("si\nno\nok")
print(s)
# Out:
# si
# no
# ok

# %% [markdown]
# Items

# %%
texto = "matematicas"
texto[:5]
# Out:
# 'matem'

# %%
texto[5:10]
# Out:
# 'atica'

# %%
len(texto)
# Out:
# 11

# %%
texto[11:]
# Out:
# ''

# %%
print("j"+texto[1:])
# Out:
# jatematicas

# %% [markdown]
# Tuplas

# %%
colores = ("rojo","verde","azul") #Se pueden concatenar (+)
colores
# Out:
# ('rojo', 'verde', 'azul')

# %% [markdown]
# Evaluacion

# %%
cadena = "hola mundo"
print(cadena)
# Out:
# hola mundo

# %%
lista=["h","o","l","a","","m","u","n","d","o"]
print(lista)
# Out:
# ['h', 'o', 'l', 'a', '', 'm', 'u', 'n', 'd', 'o']

# %%
Tupla = ("h","o","l","a","","m","u","n","d","o")
print(Tupla)
# Out:
# ('h', 'o', 'l', 'a', '', 'm', 'u', 'n', 'd', 'o')

# %% [markdown]
# Diccionario

# %%
Alumno = {"nombre": "Juan","edad": 18,"curso": "4 año"
}
Alumno #No se suman
# Out:
# {'nombre': 'Juan', 'edad': 18, 'curso': '4 año'}

# %%
Alumno["edad"]
# Out:
# 18

# %%
Alumno["nota"]=7
Alumno
# Out:
# {'nombre': 'Juan', 'edad': 18, 'curso': '4 año', 'nota': 7}

# %%
Alumno["ausencias"]=2
Alumno
# Out:
# {'nombre': 'Juan', 'edad': 18, 'curso': '4 año', 'nota': 7, 'ausencias': 2}

# %%
Alumno["ausencias"]
# Out:
# 2

# %%
del Alumno["curso"]
Alumno
# Out:
# {'nombre': 'Juan', 'edad': 18, 'nota': 7, 'ausencias': 2}

# %%
Alumno["años"]=Alumno["edad"]
Alumno
# Out:
# {'nombre': 'Juan', 'edad': 18, 'nota': 7, 'ausencias': 2, 'años': 18}

# %% [markdown]
# Conjuntos

# %%
colores = {"rojo","verde","azul"} #Los conjuntos no tienen orden ni se pueden sumar (No indexado)
colores
# Out:
# {'azul', 'rojo', 'verde'}

# %%
colores1 = {"rojo","verde","azul","verde","verde","verde"}
colores1
# Out:
# {'azul', 'rojo', 'verde'}

# %%
colores == colores1
# Out:
# True

# %%
for color in colores: print(color)
# Out:
# azul
# rojo
# verde

# %% [markdown]
# Lista en diccionario

# %%
lista2=[("nombre","ana"),("edad",19)]
diccionario = dict(lista2)
diccionario
# Out:
# {'nombre': 'ana', 'edad': 19}

# %%
lista = ["ana",19] #Es necesario organizar los elementos de la lista en duplas
dict(lista)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4201726970.py in <cell line: 0>()
#       1 lista = ["ana",19]
# ----> 2 dict(lista)
#
# ValueError: dictionary update sequence element #0 has length 3; 2 is required

# %%
lista3 = ["laura","Liz","Rob","barry"] #Es necesario enumerar los elementos para asignarles una clave
diccionario3 = dict(enumerate(lista3))
diccionario3
# Out:
# {0: 'laura', 1: 'Liz', 2: 'Rob', 3: 'barry'}

# %%
alumno1={"nombre":"Rob","edad":30,"curso":"musica"}
print(list(alumno1),tuple(alumno1))
# Out:
# ['nombre', 'edad', 'curso'] ('nombre', 'edad', 'curso')

# %%
alumno1.values()
# Out:
# dict_values(['Rob', 30, 'musica'])

# %%
list(alumno1.values())
# Out:
# ['Rob', 30, 'musica']

# %%
Alumno.items()
# Out:
# dict_items([('nombre', 'Juan'), ('edad', 18), ('nota', 7), ('ausencias', 2), ('años', 18)])
