# %% [markdown]
# <a href="https://colab.research.google.com/github/Malu247/programacion1-/blob/main/errores_y_excepciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
usuarios = {
    "ANA": "1234",
    "JUAN": "abcd"
}

try:
    usuario = input("Usuario: ").upper()
    password = input("Contraseña: ")

    if usuario not in usuarios:
        raise KeyError("El usuario no existe")

    if usuarios[usuario] != password:
        raise ValueError("Contraseña incorrecta")

    else:
        print("Bienvenido,", usuario)

except KeyError as e:
    print("Error:", e)

except ValueError as e:
    print("Error:", e)
# Out:
# Usuario: wer
# Contraseña: 234
# Error: 'El usuario no existe'

# %% [markdown]
# No muestra el error hasta no poner la contraseña

# %%
usuarios = {
    "ANA": "1234",
    "JUAN": "abcd"
}

try:
    usuario = input("Usuario: ").upper()

    if usuario not in usuarios:
        raise KeyError("El usuario no existe")

    elif usuarios[usuario] != input("Contraseña: "):
      raise ValueError("Contraseña incorrecta")

    else:
        print("Bienvenido,", usuario)

except KeyError as e:
    print("Error:", e)

except ValueError as e:
    print("Error:", e)d
    print("Error:", e)
# Out:
# Usuario: s
# Error: 'El usuario no existe'

# %%
Si el usuario no existe, muestra el error y el programa no se sigue ejecutando.

# %%
try:
  num1= float(input("Ingrese el primer número: "))
  num2= float(input("Ingrese el segundo número: "))
  op= input("Ingrese la operación a realizar (+, -, *, /): ")

  if op == "+":
    resultado = num1 + num2
  elif op == "-":
    resultado = num1 - num2
  elif op == "*":
    resultado = num1 * num2
  elif op == "/":
    resultado = (num1 / num2,"residuo:",num1%num2)
  else:
    raise ValueError("Operación no válida")

  print("El resultado de la operación es:", resultado)
except ValueError as e:
  print("Error:", e)
except ZeroDivisionError as e:
  print("Error: No se puede dividir entre cero")
# Out:
# Ingrese el primer número: 2
# Ingrese el segundo número: 6
# Ingrese la operación a realizar (+, -, *, /): /
# El resultado de la operación es: (0.3333333333333333, 'residuo:', 2.0)

# %%
try:
    num1 = float(input("Ingrese el primer número: "))
    num2 = float(input("Ingrese el segundo número: "))
    op = input("Ingrese la operación a realizar (+, -, *, /): ")

    if op == "+":
        resultado = num1 + num2
    elif op == "-":
        resultado = num1 - num2
    elif op == "*":
        resultado = num1 * num2
    elif op == "/":
        resultado = (num1 / num2, "residuo:", num1 % num2)
    else:
        raise ValueError("Operación no válida")

    print("El resultado de la operación es:", resultado)

except Exception as e:
    print("Error:", e)
    exit()
# Out:
# Ingrese el primer número: e
# Error: could not convert string to float: 'e'

# %% [markdown]
# El programa deja de ejecutarse al momento de detectar el primer error.

# %%
try:
  num1= (input("Ingrese el primer número: "))
  num2= (input("Ingrese el segundo número: "))
  op= input("Ingrese la operación a realizar (+, -, *, /): ")

  if op == "+":
    resultado = num1 + num2
  elif op == "-":
    resultado = num1 - num2
  elif op == "*":
    resultado = num1 * num2
  elif op == "/":
    resultado = num1 / num2
  else:
    raise ValueError("Operación no válida")

  print("El resultado de la operación es:", resultado)
except ValueError as e:
  print("Error:", e)
except ZeroDivisionError as e:
  print("Error: No se puede dividir entre cero")
except TypeError as e:
  print("Error:", e)
# Out:
# Ingrese el primer número: 5
# Ingrese el segundo número: 6
# Ingrese la operación a realizar (+, -, *, /): /
# Error: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# El input toma lo ingresado pr el usuario como una cadena, por lo que si no se le agrega un int o float, el numero será tomado como texto y al momento de realizar la operacion entre cadenas ocurre un error.

# %%
try:
    datos = input("Ingresa números separados por coma: ")
    lista = [int(x) for x in datos.split(",")]

    indice = int(input("Índice a consultar: "))
    print("Elemento:", lista[indice])

except ValueError:
    print("Debes ingresar solo números")

except IndexError:
    print("El índice está fuera de rango")

except TypeError:
    print("Los indices son numeros enteros")
# Out:
# Ingresa números separados por coma: 2,3,4,5
# Índice a consultar: 4.5
# Debes ingresar solo números
