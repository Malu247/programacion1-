# %% [markdown]
# <a href="https://colab.research.google.com/github/Malu247/programacion1-/blob/main/Quiz5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("archivo.txt","w") as f:
  f.write("Hola, este es un archivo de texto.\n")
  f.write("Segunda linea.\n")

# %%
with open("archivo.txt","r") as f:
  print(f.read())
# Out:
# Hola, este es un archivo de texto.
# Segunda linea.

# %%
from google.colab import files
files.download("archivo.txt")

# %%
with open("archivo.txt","a") as f:
  f.write("\nesta es una nueva linea")

# %%
with open("TxT.txt", "w") as f:
  f.write("Choi Soobin, Choi Yeonjun, Choi Beomgyu, Kang Taehyun, Hueninkai")
  f.write("Tomorrow by Together")

# %%
with open("archivo.txt","a") as f:
  f.write("\nChoi Soobin, Choi Yeonjun, Choi Beomgyu, Kang Taehyun, Hueninkai")
  f.write("\nTomorrow by Together")

# %%
with open("archivo (1).txt", "w") as f:
  f.write("Este archivo fue completamente modificado\n")
  f.write("Nueva lines\n")
  f.write("nueva linea 2\n")

# %%
with open("archivo (1).txt", "r") as f:
  print(f.read())
# Out:
# Este archivo fue completamente modificado
# Nueva lines
# nueva linea 2

# %%
from google.colab import files
files.download("archivo (1).txt")

# %%
import csv
datos = [["Nombre","Edad", "Grupo"], ["Yeonjun", 26, "txt"], ["Namjoon", 32, "bts"], ["Karina", 26, "aespa" ]]

with open("datos.csv", "w", newline="") as f:
  writer = csv.writer(f)
  writer.writerows(datos)

# %%
with open("datos.csv", "r") as f:
  print(f.read())
# Out:
# Nombre,Edad,Grupo
# Yeonjun,26,txt
# Namjoon,32,bts
# Karina,26,aespa

# %%
files.download("datos.csv")

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
ruta = "/content/drive/MyDrive/datos.csv"
import shutil
shutil.copy("datos.csv", ruta)
# Out:
# '/content/drive/MyDrive/datos.csv'

# %%
with open(ruta, "r") as f:
  print(f.read())
# Out:
# Nombre,Edad,Grupo
# Yeonjun,26,txt
# Namjoon,32,bts
# Karina,26,aespa

# %%
with open(ruta, "r") as f:
  data = list(csv.reader(f))

data.append(["Sunoo", 25, "enhypen"])
data
# Out:
# [['Nombre', 'Edad', 'Grupo'],
#  ['Yeonjun', '26', 'txt'],
#  ['Namjoon', '32', 'bts'],
#  ['Karina', '26', 'aespa'],
#  ['Sunoo', 25, 'enhypen']]

# %%
import csv

ruta = "/content/drive/MyDrive/datos.csv"

# Leer
with open(ruta, "r") as f:
    data = list(csv.reader(f))

# Mostrar antes
print("ANTES:")
print(data)

# Agregar fila
data.append(["Felix", 26, "stray kids"])

# Guardar
with open(ruta, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(data)

# Mostrar después
print("\nDESPUÉS:")
with open(ruta, "r") as f:
    print(f.read())
# Out:
# ANTES:
# [['Nombre', 'Edad', 'Grupo'], ['Yeonjun', '26', 'txt'], ['Namjoon', '32', 'bts'], ['Karina', '26', 'aespa'], ['Diego', '28', 'Armenia'], ['Diegu', '28', 'Armenia']]
#
# DESPUÉS:
# Nombre,Edad,Grupo
# Yeonjun,26,txt
# Namjoon,32,bts
# Karina,26,aespa
# Diego,28,Armenia
# Diegu,28,Armenia
# Felix,26,stray kids

# %%
import os
os.listdir("/content/drive/MyDrive")
# Out:
# ['Géneros de los palancas.gdoc',
#  'Classroom',
#  'Hoja de cálculo sin título.gsheet',
#  'IMG_4788.jpeg',
#  'Colab Notebooks',
#  'datos.csv']

# %%
import pandas as pd
df = pd.read_csv(ruta)
df
# Out:
#     Nombre  Edad       Grupo
# 0  Yeonjun    26         txt
# 1  Namjoon    32         bts
# 2   Karina    26       aespa
# 3    Diego    28     Armenia
# 4    Diegu    28     Armenia
# 5    Felix    26  stray kids
