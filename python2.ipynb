# %% [markdown]
# <a href="https://colab.research.google.com/github/Malu247/programacion1-/blob/main/python2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
edad = 20
tiene_cedula = True
if edad >=18 and tiene_cedula:
  print("Puede votar")
else:
  print("No puede votar")
# Out:
# Puede votar

# %%
dia = "Sabado"
if dia == "Sabado" or dia == "Domingo":
  print("Es fin de semana")
# Out:
# Es fin de semana

# %%
letra = ["A", "B", "C", "D", "E"]
for i in letra:
  if i == "A" or i == "E":
    print("vocal")
    break #para tomar solo un elemento y no todos los elementos
# Out:
# vocal

# %%
i = input("Ingrese el día (L, M, Mu, J, V, S, D)")
dia = ["L", "M", "Mi", "J", "V", "S", "D"]
for i in dia:
  if i == "S" or i == "D":
    print("Fin de semana") #Esta mal
    break
  else:
    print("Entre semana")
    break
# Out:
# Ingrese el día (L, M, Mu, J, V, S, D)D
# Entre semana

# %%
i = input("Ingrese el día (L, M, Mu, J, V, S, D)")
dia = ["L", "M", "Mi", "J", "V"]
while i in dia:
    print("Entre semana")
    break
else:
    print("Fin de semana")
# Out:
# Ingrese el día (L, M, Mu, J, V, S, D)J
# Entre semana

# %%
a = True
b = False
if a ^ b:
  print("XOR verdadero")
else:
  print("XOR falso")
# Out:
# XOR verdadero

# %%
usuario = input("usuario")
contraseña = input("contraseña")
if usuario == "admin" and contraseña == "123":
  print("Acceso concedido")
else:
  print("Acceso denegado")
# Out:
# usuarioadmin
# contraseña123
# Acceso concedido

# %%
for n in range(0, 10):
  if n == 1 or n == 0:
    print("El número es ", n)
  else:
    for x in range(2, n):
      if n % x == 0:
          print(n, 'es igual a', x, '*', n // x)
          break
    else: # Este else corresponde al for, no al if
      print(n, 'es un número primo')
# Out:
# El número es  0
# El número es  1
# 2 es un número primo
# 3 es un número primo
# 4 es igual a 2 * 2
# 5 es un número primo
# 6 es igual a 2 * 3
# 7 es un número primo
# 8 es igual a 2 * 4
# 9 es igual a 3 * 3

# %%
lista = [10, 20, 30]
try:
    index = int(input("Ingresa un índice: "))
    print("El valor es:", lista[index])
except IndexError: # Indice fuera de rango
    print("Índice fuera de rango")
except ValueError: # Cuando ingresamos un valor no permitido
    print("Debes ingresar un número entero")

# %%
tupla = (10, 20, 30, 40, 50)
try:
    index = int(input("Ingresa un índice: "))
    print("El valor es:", tupla[index])
except IndexError: # Indice fuera de rango
    print("Índice fuera de rango")
except ValueError: # Cuando ingresamos un valor no permitido
    print("Debes ingresar un número entero")
# Out:
# Ingresa un índice: 4
# El valor es: 50

# %%
x = 5
x+= 5 # Suma y se toma el valor del x anterior
x+= 5
print(x)
# Out:
# 15

# %%
clave_correcta = "python123"
intento = ""
while intento != clave_correcta:
    intento = input("Ingresa la contraseña: ")
print("¡Acceso concedido!")
# Out:
# Ingresa la contraseña: python
# Ingresa la contraseña: dasd
# Ingresa la contraseña: python123
# ¡Acceso concedido!

# %%
clave_correcta = "python123"
intento = ""
while intento != clave_correcta:
    intento = input("Ingresa la contraseña: ")
print("¡Acceso concedido!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-70367331.py in <cell line: 0>()
#       2 intento = ""
#       3 while intento != clave_correcta:
# ----> 4     intento = input("Ingresa la contraseña: ")
#       5 print("¡Acceso concedido!")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
clave_correcta = "python123"
intentos = 3
while intentos > 0:
  intento = input("Ingresa la contraseña: ")
  if intento == clave_correcta:
    print("¡Acceso concedido!")
    break
  else:
    intentos -= 1
    print("intentos restantes", intentos)
else:
  print("cuenta bloqueada")
# Out:
# Ingresa la contraseña: sadsa
# intentos restantes 2
# Ingresa la contraseña: dasd
# intentos restantes 1
# Ingresa la contraseña: python123
# ¡Acceso concedido!
