# %% [markdown]
# <a href="https://colab.research.google.com/github/Malu247/programacion1-/blob/main/Metodos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cadena1 = "Quiero papas de tomate"

# %%
dir(cadena1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
cadena1.__len__() #len como un metodo
# Out:
# 22

# %%
len(cadena1) #len como una funcion
# Out:
# 22

# %%
cadena1.upper()
# Out:
# 'QUIERO PAPAS DE TOMATE'

# %%
cadena1.lower()
# Out:
# 'quiero papas de tomate'

# %%
cadena1.capitalize()
# Out:
# 'Quiero papas de tomate'

# %%
cadena1.islower()
# Out:
# False

# %%
cadena2 = "hola mundo"

# %%
cadena2.capitalize()
# Out:
# 'Hola mundo'

# %%
cadena2.islower()
# Out:
# False

# %%
def mayusculas(cadena):
  return print(cadena.upper(), cadena.isupper())
mayusculas("casa")
# Out:
# CASA False

# %%
busqueda = cadena1.find("t")
busqueda
# Out:
# 16

# %%
indice = cadena1.index("o")
indice
# Out:
# 5

# %%
indice = cadena1.index("w")
indice
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1643/2070293345.py in <cell line: 0>()
# ----> 1 indice = cadena1.index("w")
#       2 indice
#
# ValueError: substring not found

# %%
busqueda = cadena1.find("")
busqueda
# Out:
# 0

# %%
busqueda = cadena1.find("w")
busqueda
# Out:
# -1

# %%
"12314".isnumeric()
# Out:
# True

# %%
"hola1234".isnumeric()
# Out:
# False

# %%
"hola1234".isalnum()
# Out:
# True

# %% [markdown]
# La cadena vacia pertenece a todas las cadenas

# %%
" ".isspace()
# Out:
# True

# %%
cadena1.count("e")
# Out:
# 3

# %%
cadena1.startswith("Q")
# Out:
# True

# %%
cadena1.endswith("e")
# Out:
# True

# %%
cadena_nueva = cadena1.replace("tomate", "limon")
cadena_nueva
# Out:
# 'Quiero papas de limon'

# %%
cadena_nueva = cadena1.replace("pollo", "limon")
cadena_nueva
# Out:
# 'Quiero papas de tomate'

# %%
cadena_nueva2 = cadena_nueva.replace(" ","")
cadena_nueva2
# Out:
# 'Quieropapasdetomate'

# %%
cadena1.split()
# Out:
# ['Quiero', 'papas', 'de', 'tomate']

# %%
len(cadena1.split())
# Out:
# 4

# %%
cadena_nueva2.split()
# Out:
# ['Quieropapasdetomate']

# %%
cadena7 = "hola  chao "
cadena7.split()
# Out:
# ['hola', 'chao']

# %%
lista1 = ["a","b","c","d","e","f","g","h"]
print(lista1)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
lista1.insert(3, "c")
print(lista1)
# Out:
# ['a', 'b', 'c', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
print(lista1.append("i"))
lista1
# Out:
# None
# ['a', 'b', 'c', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'i']

# %%
listavacia = []
listavacia.append(2)
listavacia
# Out:
# [2]

# %%
lista1.extend(["j","k","m"])
lista1
# Out:
# ['a', 'b', 'c', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'i', 'j', 'k', 'm']

# %%
lista1.pop(-1)
lista1
# Out:
# ['a', 'b', 'c', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'i', 'j', 'k']

# %%
lista1.remove("i")
lista1
# Out:
# ['a', 'b', 'c', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']

# %%
while "i" in lista1:
  lista1.remove("i")
lista1
# Out:
# ['a', 'b', 'c', 'c', 'd', 'e', 'f', 'g', 'h', 'j', 'k']

# %%
lista2 = ["b","c","a"]
lista2.sort()
lista2
# Out:
# ['a', 'b', 'c']

# %%
lista2.reverse()
lista2
# Out:
# ['c', 'b', 'a']

# %%
lista2.sort(reverse=True)
lista2
# Out:
# ['c', 'b', 'a']

# %%
tupla1 = (1,2,3,4,5,6,7,8)
tupla1
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)

# %%
tupla1.append(9) #La tupla es un elemento inmutable
tupla1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1643/2001257131.py in <cell line: 0>()
# ----> 1 tupla1.append(9)
#       2 tupla1
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tupla1.extend((9,10,11))
tupla1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1643/3185967669.py in <cell line: 0>()
# ----> 1 tupla1.extend((9,10,11))
#       2 tupla1
#
# AttributeError: 'tuple' object has no attribute 'extend'

# %%
tupla1.index(2)
# Out:
# 1

# %%
dir(tupla1)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
tupla1.count(8)
# Out:
# 1

# %%
conjunto1 = {1,2,3,4,5}
conjunto1.add("a")
conjunto1
# Out:
# {1, 2, 3, 4, 5, 'a'}

# %%
conjunto1.remove(4)
conjunto1
# Out:
# {1, 2, 3, 5, 'a'}
