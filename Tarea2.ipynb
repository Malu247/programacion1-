# %% [markdown]
# <a href="https://colab.research.google.com/github/Malu247/programacion1-/blob/main/Tarea2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Video 1**

# %% [markdown]
# Listas

# %%
lista = [12, False, 8237982.894789, "hola mundo"]
print(lista)
# Out:
# [12, False, 8237982.894789, 'hola mundo']

# %%
print(lista[3])
# Out:
# hola mundo

# %%
print(lista[-1])
# Out:
# hola mundo

# %%
print(lista[1:3])
# Out:
# [False, 8237982.894789]

# %%
lista[1] = True
print(lista)
# Out:
# [12, True, 8237982.894789, 'hola mundo']

# %%
lista_nueva = [1,2,3,4]
lista_nueva.append(5)
print(lista_nueva)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(lista_nueva.count(3))
# Out:
# 1

# %%
print(lista_nueva.index(1))
# Out:
# 0

# %%
lista_nueva.remove(3)
print(lista_nueva)
# Out:
# [1, 4]

# %% [markdown]
# Tuplas

# %%
tupla = (123, True, 12.3233123, "hola mundo")
print(tupla)
# Out:
# (123, True, 12.3233123, 'hola mundo')

# %%
print(tupla.count(123))
# Out:
# 1

# %%
print(tupla.index(True))
# Out:
# 1

# %% [markdown]
# Conjuntos

# %%
print(set([1,2,3,4]))
print(set((1,2,3,4)))
print(set("1,2,3,4"))
# Out:
# {1, 2, 3, 4}
# {1, 2, 3, 4}
# {'3', ',', '2', '4', '1'}

# %%
conjunto = set([2,3,3,3,4])
print(conjunto)
# Out:
# {2, 3, 4}

# %%
conjunto.add(1)
print(conjunto)
# Out:
# {1, 2, 3, 4}

# %%
conjunto.remove(1)
print(conjunto)
# Out:
# {2, 3, 4}

# %%
conjunto2 = {5,6,7}
conjunto3 = {4,2,8}
print(conjunto, conjunto2, conjunto3)
# Out:
# {2, 3, 4} {5, 6, 7} {8, 2, 4}

# %%
print(conjunto.intersection(conjunto3))
# Out:
# {2, 4}

# %%
print(conjunto2.issubset(conjunto))
# Out:
# False

# %%
print(conjunto3.issubset(conjunto))
# Out:
# False

# %%
print(conjunto ^ conjunto3)
# Out:
# {8, 3}

# %% [markdown]
# Diccionarios

# %%
diccionario = {"nombre": "Juan","edad": 20}
print(diccionario)
# Out:
# {'nombre': 'Juan', 'edad': 20}

# %%
print(diccionario["nombre"])
# Out:
# Juan

# %%
diccionario["edad"] = 25
print(diccionario)
# Out:
# {'nombre': 'Juan', 'edad': 25}

# %%
print(diccionario, diccionario.keys(), diccionario.values(), diccionario.items())
# Out:
# {'nombre': 'Juan', 'edad': 25} dict_keys(['nombre', 'edad']) dict_values(['Juan', 25]) dict_items([('nombre', 'Juan'), ('edad', 25)])

# %%
diccionario.pop("edad")
print(diccionario)
# Out:
# {'nombre': 'Juan'}

# %% [markdown]
# Ejercicios

# %%
personajes = ["pikachu", "squirtle", "charizard"]
personajes.remove("pikachu")
personajes.append("ditto")
resultado = personajes[1:2]
print(resultado)
# Out:
# ['charizard']

# %%
respuesta = ("Yes","Yes","Yes")
resultado = (respuesta.count("Yes"), respuesta.index("Yes"))
print(resultado)
# Out:
# (3, 0)

# %%
temporada_2 = set(["kirito", "asuna"])
temporada_3 = set(["joe", "kirito", "sakura", "Kakyoin", "Polnareff"])
resultado = temporada_2 & temporada_3
print(resultado)
# Out:
# {'kirito'}

# %%
lideres = {1: "RM", 2: "Jungwon", 3: "Soobin"}
grupos = {"RM": "BTS",
         "Jungwon": "Enhypen",
         "Soobin": "TxT"}
resultado = grupos[lideres[3]]
print(resultado)
# Out:
# TxT

# %% [markdown]
# **Video 2**

# %% [markdown]
# If y else

# %%
edad = float(input("Introduzca su edad: "))
if edad < 18:
  print("Eres menor de edad, no puedes votar")
# Out:
# Introduzca su edad: 13
# Eres menor de edad, no puedes votar

# %%
edad = float(input("Introduzca su edad: "))
if edad < 18:
  print("Eres menor de edad, no puedes votar")
else:
  print("Eres mayor de edad, puedes votar")
# Out:
# Introduzca su edad: 23
# Eres mayor de edad, puedes votar

# %% [markdown]
# Elif

# %%
nota = float(input("Introduzca su nota: "))
if 0 <= nota and nota < 5:
  print("Reproado")
elif 5 <= nota and nota < 7:
  print("Basico")
elif 7 <= nota and nota < 9:
  print("Alto")
elif 9 <= nota and nota <= 10:
  print("Superior")
else:
  print("Nota no valida")
# Out:
# Introduzca su nota: 4
# Reproado

# %% [markdown]
# While

# %%
contador = 10
while contador >0:
  contador = contador - 1
  print("El contenido de contador es", contador)
# Out:
# El contenido de contador es 9
# El contenido de contador es 8
# El contenido de contador es 7
# El contenido de contador es 6
# El contenido de contador es 5
# El contenido de contador es 4
# El contenido de contador es 3
# El contenido de contador es 2
# El contenido de contador es 1
# El contenido de contador es 0

# %% [markdown]
# For

# %%
lista = list((2, 1, 0))
tupla = tuple((2, 1, 0))
conjunto = set((2, 1, 0))
diccionario = dict(((2,"Dos"), (1, "Uno"), (0, "Cero")))

for iterador in lista:
  print(iterador)
# Out:
# 2
# 1
# 0

# %%
lista = list((2, 1, 0))
tupla = tuple((2, 1, 0))
conjunto = set((2, 1, 0))
diccionario = dict(((2,"Dos"), (1, "Uno"), (0, "Cero")))

for iterador in conjunto:
  print(iterador)
# Out:
# 0
# 1
# 2

# %%
lista = list((2, 1, 0))
tupla = tuple((2, 1, 0))
conjunto = set((2, 1, 0))
diccionario = dict(((2,"Dos"), (1, "Uno"), (0, "Cero")))

for iterador in diccionario.items():
  print(iterador)
# Out:
# (2, 'Dos')
# (1, 'Uno')
# (0, 'Cero')

# %%
lista = ["Bienvenido", "a", "Phyton"]

for indice in range(len(lista)):
  print("Indice:", indice,"Elemento:", lista[indice])
# Out:
# Indice: 0 Elemento: Bienvenido
# Indice: 1 Elemento: a
# Indice: 2 Elemento: Phyton

# %% [markdown]
# Break y Continue

# %%
for numero in range(5):
  if numero == 3:
    break
  print(numero)
# Out:
# 0
# 1
# 2

# %%
for numero in range(5):
  if numero == 3:
    continue
  print(numero)
# Out:
# 0
# 1
# 2
# 4

# %%
intentos = 2
while intentos > 0:
  if input("Escriba la contraseña:") == "247":
    print("¡Correcta!")
    break
  intentos = intentos - 1
  print("Contraseña incorrecta")
else:
  print("Se te acabaron los intentos :(")
# Out:
# Escriba la contraseña:23
# Contraseña incorrecta
# Escriba la contraseña:44
# Contraseña incorrecta
# Se te acabaron los intentos :(

# %%
intentos = 2
while intentos > 0:
  if input("Escriba la contraseña:") == "247":
    print("¡Correcta!")
    break
  intentos = intentos - 1
  print("Contraseña incorrecta")
else:
  print("Se te acabaron los intentos :(")
# Out:
# Escriba la contraseña:247
# ¡Correcta!
