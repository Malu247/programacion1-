# %% [markdown]
# <a href="https://colab.research.google.com/github/Malu247/programacion1-/blob/main/Errores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Manejo de errores

# %%
x = 10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_1749/4001962833.py in <cell line: 0>()
# ----> 1 x = 10/0
#
# ZeroDivisionError: division by zero

# %%
try:
  x = int(input("Introduce un numero: "))
  print(10/x)
except:
    print("Ha ocurrido un error")
# Out:
# Introduce un numero: 0
# Ha ocurrido un error

# %%
try:
  x = int(input("Introduce un numero: "))
  print(10/x)
except:
    pass
# Out:
# Introduce un numero: 0

# %%
try:
  x = int(input("Introduce un numero: "))
  print(10/x)
except ValueError:
    print("Debes introducir un numero")
except ZeroDivisionError:
    print("No puedes dividir entre 0")
# Out:
# Introduce un numero: E
# Debes introducir un numero

# %%
try:
  lista=[1,2,3,4]
  print(lista[9])
except (IndexError, TypeError) as e:
  print(f"Ocurrio un error: {e}")
# Out:
# Ocurrio un error: list index out of range

# %%
lista=[1,2,3,4]
x = int(input("Introduce un numero: "))
try:
  print(lista[x])
except (IndexError, TypeError) as e:
  print(f"Ocurrio un error: {e}")
# Out:
# Introduce un numero: 8
# Ocurrio un error: list index out of range

# %%
lista=[1,2,3,4]
try:
  x = int(input("Introduce un numero: "))
  print(lista[x])
except (IndexError, TypeError, ValueError) as e:
  print(f"Ocurrio un error: {e}")
# Out:
# Introduce un numero: -9
# Ocurrio un error: list index out of range

# %%
try:
  x = int(input("Introduce un numero: "))
except ValueError:
  print("Debes introducir un numero")
else:
  print("Todo bien", x)
finally:
  print("Esto siempre se ejecuta")
# Out:
# Introduce un numero: s
# Debes introducir un numero
# Esto siempre se ejecuta

# %%
try:
  edad = int(input("edad: "))
  if edad < 0:
    raise ValueError("La edad no puede ser negativa") #Errores personalizados
  print("edad valida", edad)
except ValueError as e:
  print("Error", e)
# Out:
# edad: -7
# Error La edad no puede ser negativa

# %% [markdown]
# Tipos comunes de errores en Python

# %%
int("adsdasdsa")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1749/3121259353.py in <cell line: 0>()
# ----> 1 int("adsdasdsa")
#
# ValueError: invalid literal for int() with base 10: 'adsdasdsa'

# %%
try:
  dato = input("Ingresa un numero: ")
  numero = float(dato)
  print("Numero", numero)
except ValueError as e:
  print("ValueError", e
        )
# Out:
# Ingresa un numero: y
# ValueError could not convert string to float: 'y'

# %%
try:
  dato = input("Ingresa un numero: ")
  numero = complex(dato)
  print("Numero", numero)
except ValueError as e:
  print("ValueError", e)
# Out:
# Ingresa un numero: s
# ValueError complex() arg is a malformed string

# %%
"hola" + "5"
# Out:
# 'hola5'

# %%
"hola" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1749/1776980920.py in <cell line: 0>()
# ----> 1 "hola" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
"hola" * 3
# Out:
# 'holaholahola'

# %%
try:
  texto = input("Ingresa un texto: ")
  numero = int(input("Ingresa un numero: "))
  resultado = texto + numero
  print(resultado)
except TypeError as e:
    print("TypeError", e)
# Out:
# Ingresa un texto: eskere
# Ingresa un numero: 96
# TypeError can only concatenate str (not "int") to str

# %%
lista = [1,2,3]
lista[5] #Error de indexacion
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1749/1525254907.py in <cell line: 0>()
#       1 lista = [1,2,3]
# ----> 2 lista[5] #Error de indexacion
#
# IndexError: list index out of range

# %%
try:
  lista = input("Ingrese elementos separados por comas:").split(",")
  indice = int(input("Ingrese un indice: "))
  print("Elemento", lista[indice])
except IndexError as e:
  print("IndexError", e)
except ValueError as e:
  print("ValueError", e)
# Out:
# Ingrese elementos separados por comas:2,3,4,5,5
# Ingrese un indice: s
# ValueError invalid literal for int() with base 10: 's'

# %%
dic ={"a": 3}
dic["b"] #Error de clave
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1749/2342474977.py in <cell line: 0>()
#       1 dic ={"a": 3}
# ----> 2 dic["b"] #Error de clave
#
# KeyError: 'b'

# %%
try:
  dic = {4:1, 6:2}
  clave = int(input("Ingrese una clave: "))
  print("Valor", dic[clave])
except (KeyError, ValueError) as e:
  print("KeyError", e)
# Out:
# Ingrese una clave: d
# KeyError invalid literal for int() with base 10: 'd'

# %%
print(rata) #Variable no definida
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1749/3689194552.py in <cell line: 0>()
# ----> 1 print(rata)
#
# NameError: name 'rata' is not defined

# %%
raton = 3
try:
  a = input("Escriba el nombre de la variable")
  print(eval(a)) #Eval evalua que es el objeto
except NameError as e:
  print("NameError", e)
# Out:
# Escriba el nombre de la variabled
# NameError name 'd' is not defined

# %%
try:
  a = float(input("Numerador: "))
  b = float(input("Denominador: "))
  print("Resultado", a/b)
except ZeroDivisionError as e:
  print("Al dividir entre cero se obtiene una indeterminacion:  ", e)
# Out:
# Numerador: 2
# Denominador: 0
# Al dividir entre cero se obtiene una indeterminacion:   float division by zero

# %%
try:
  a = int(input("Numero:"))
  b = input("Cadena: ")
  print("producto:", a*b)
except TypeError:
  print("no se puede multiplicar un numero por una cadena")
# Out:
# Numero:3
# Cadena: 3e
# producto: 3e3e3e

# %%
x = 5
x.append(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1749/2030815935.py in <cell line: 0>()
#       1 x = 5
# ----> 2 x.append(10)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
try:
  dato = input("Ingresa un numero: ")
  numero = float(dato)
  dato.

# %%
open("archivo_inexistente.txt") #archivo que no existe
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1749/1532673078.py in <cell line: 0>()
# ----> 1 open("archivo_inexistente.txt") #archivo que no existe
#
# FileNotFoundError: [Errno 2] No such file or directory: 'archivo_inexistente.txt'
