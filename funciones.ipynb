# %% [markdown]
# <a href="https://colab.research.google.com/github/Malu247/programacion1-/blob/main/funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def saludar():
  "La funcion que saluda"
  print("hola")

# %%
saludar()
# Out:
# hola

# %%
saludar
# Out:
# <function __main__.saludar()>

# %%
def saludar(nombre):
  print("Hola", nombre)
saludar("ana")
# Out:
# Hola ana

# %%
def sumar(a, b):
  return a + b

# %%
resultado = sumar(a=3, b=5)
resultado
# Out:
# 8

# %%
def area(b, h):
  return b*h/2

# %%
resultado = area(b= 10, h=5)
resultado
# Out:
# 25.0

# %%
def saludar(nombre="estudiante"):
  print("holi", nombre)

saludar()
saludar(nombre="Logan")
# Out:
# holi estudiante
# holi Logan

# %%
def operaciones(a, b):
  suma = a + b
  resta = a - b
  return suma, resta

s, r = operaciones(b= 10, a =23)
print(s, r)
# Out:
# 33 13

# %%
def operaciones(a):
  multiplicacion = a*5
  cuadrado = a**2
  return multiplicacion, cuadrado

m, c = operaciones(a =23)
print(m, c)
# Out:
# 115 529
